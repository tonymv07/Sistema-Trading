# %%
import os
import requests
import datetime
from datetime import date, timedelta

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'da62bf9d-971f-4a45-abd1-d6c558606b01',
}

response = requests.get(url, params = parameters, headers = headers)
data = response.json()['data']
today = date.today()
yesterday = str(today - timedelta(days=2))
yesterday_datetime = datetime.datetime.strptime(yesterday, '%Y-%m-%d')
 

try:

    for i in range(0,len(data), 1):
        name = data[i]['slug']
        date_added_str = data[i]['date_added'][:10]
        date_added = datetime.datetime.strptime(date_added_str, '%Y-%m-%d')

        if yesterday_datetime < date_added:
            print(name," : ",date_added_str)

        #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)

# %%
import websocket, json

cc = 'btcusd'
interval = '1m' 

socket = f"wss://stream.binance.com:9443/ws/btcusdt@kline_1m"

def on_message(ws, message):
    print(message)
    
def on_close(ws):
    print("Connection Closed")

ws = websocket.WebSocketApp(socket,on_message = on_message, on_close = on_close)

ws.run_forever()

# %%
import os
import requests
import datetime
from datetime import date, timedelta

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'10',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'da62bf9d-971f-4a45-abd1-d6c558606b01',
}

response = requests.get(url, params = parameters, headers = headers)
data = response.json()['data']
print(data)

# %%
import os
import requests
import datetime
from datetime import date, timedelta

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'da62bf9d-971f-4a45-abd1-d6c558606b01',
}

response = requests.get(url, params = parameters, headers = headers)
data = response.json()['data']
today = date.today()
yesterday = str(today - timedelta(days=2))
yesterday_datetime = datetime.datetime.strptime(yesterday, '%Y-%m-%d')
listOld = []
 

try:
    
    listNew = []

    for i in range(0,len(data), 1):
        name = data[i]['slug']
        date_added_str = data[i]['date_added'][:10]
        date_added = datetime.datetime.strptime(date_added_str, '%Y-%m-%d')

        if yesterday_datetime < date_added:
            listNew.append(name)
            #print(name," : ",date_added_str)

    print(listNew)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# ['solarmine', 'monster-adventure-token', 'guildfi', 'vibranium-token', 'son-of-doge', 'infinitycash', 'meta-billionaires-club', 'shiba-metaverse-shim', 'the-crypto-you', 'waves-exchange-token', 'empire-capital-token', 'pnessmonster', 'metaverse-exchange', 'floshin-token', 'dopewarz', 'meta-rewards-token', 'rematic', 'abura-farm', 'watchsports', 'king-shiba-inu', 'midasdao', 'blackpoker', 'hodl-vault-token', 'shibagalaxy', 'wasdaq-finance', 'terrausd-wormhole', 'tabtrader-token', 'solar-full-cycle', 'kounotori', 'metazoon', 'mufasa-inu', 'ruffy-coin', 'squid-finance', 'kalissa', 'pussycat', 'musk-metaverse', 'magic-forest', 'honey-deluxe-token', 'babylosercoin', 'blue-gold', 'simpli-finance', 'xtremcoin', 'upfund', 'shiba-heist', 'forevergrow', 'buffaloswap-horn', 'astrodonkey', 'shiba-dragon', 'redfrunk', 'ltradex', 'gforce', 'roarts-token', 'atrollcity', 'iceflake-finance', 'wen-lambo', 'sriracha-inu', 'kryza-exchange', 'doges-among-us', 'ava-mim', 'merryxrpmas', 'grim-finance', 'shibana', 'cryptotem', 'synex-coin', 'wmt']

# %%
l1 = ['btc','eth','bnb']
l2 = ['btc','eth','bnb','sol','ant']
new = []
vali = False

            
for i in l2:
    if i not in l1:
        new.append(i)
        vali = True

if vali == True:
    print("Hay monedas nuevas:\n")
    for i in new:
        print(i)

else:
    print("No hay monedas nuevas")
# Out:
# No hay monedas nuevas
# ['btc', 'eth', 'bnb', 'sol', 'ant']

# %%
import requests
import json 
import time
from bs4 import BeautifulSoup


class main_coin():
        def get_current_price_btc(self):
            url = "https://api.coingecko.com/api/v3/coins/bitcoin"
            payload = {}
            headers = {}
            response = requests.request("GET", url, headers=headers, data=payload)
            USD_coin = float(response.json()["market_data"]["current_price"]["usd"])
            return USD_coin
        def main(self):
            datos = requests.get('https://www.coingecko.com/es/monedas/recently_added').content
            soup = BeautifulSoup(datos, 'html.parser')
            data_all_coins = []
            value_btc_usd = self.get_current_price_btc()
            for a_tag in soup.findAll("i"):
                symbol = a_tag.attrs.get('data-coin-symbol')
                id = a_tag.attrs.get('data-coin-id')
                name = a_tag.attrs.get('data-coin-slug')
                price_btc = a_tag.attrs.get('data-price-btc')
                last_added = a_tag.attrs.get('trade p-0 col-market pl-2 text-center')
                data_coin = {}
                data_coin["symbol"] = ""
                data_coin["id"] = ""
                data_coin["name"] = ""
                data_coin["price_btc"] = "" 
                data_coin["last_added"] = ""
                if symbol != None and  id != None and name != None and price_btc != None:
                        data_coin["symbol"] = symbol
                        data_coin["id"] = id
                        data_coin["name"] = name
                        data_coin["price_btc"] = "{:.15f}".format(float(price_btc) * value_btc_usd)
                        data_all_coins.append(data_coin)
            i = 0
            for a_tag in soup.findAll("td", {'class':'trade p-0 col-market pl-2 text-center'}): 
                data_all_coins[i]["last_added"] = a_tag.get_text('self.get_current_price_btc').replace("\n", "")
                i = i + 1

            for obj in data_all_coins:
                print(obj)
                
main_coin().main()
def new_coins():
    list_coins="main_coin().main()"
    return list_coins
while new_coins == True:
    time.sleep(0.5)
# Out:
# {'symbol': 'arc', 'id': '21270', 'name': 'arcadenetwork', 'price_btc': '0.143606797740484', 'last_added': '10 minutos'}
# {'symbol': 'abu', 'id': '21269', 'name': 'abura-farm', 'price_btc': '0.005040415968664', 'last_added': '29 minutos'}
# {'symbol': 'wsdq', 'id': '21268', 'name': 'wasdaq-finance', 'price_btc': '0.027667481173120', 'last_added': '1 hora'}
# {'symbol': 'wx', 'id': '21267', 'name': 'waves-exchange', 'price_btc': '9.696613592255098', 'last_added': '1 hora'}
# {'symbol': 'zenith', 'id': '21266', 'name': 'zenith-chain', 'price_btc': '0.771724154791235', 'last_added': '2 horas'}
# {'symbol': 'simpli', 'id': '21264', 'name': 'simpli-finance', 'price_btc': '0.020814758776512', 'last_added': '2 horas'}
# {'symbol': 'blg', 'id': '21263', 'name': 'blue-gold', 'price_btc': '0.000000000995311', 'last_added': '2 horas'}
# {'symbol': 'flake', 'id': '21262', 'name': 'iceflake-finance', 'price_btc': '112.723671572991336', 'last_added': '2 horas'}
# {'symbol': 'kali', 'id': '21261', 'name': 'kalissa', 'price_btc': '0.077495878394144', 'last_added': '3 horas'}
# {'symbol': 'bacon', 'id': '21259', 'name': 'bacon', 'price_btc': '1.436254321793448', 'last_added': '17 horas'}
# {'symbol': 'horn', 'id': '21258', 'name': 'buffaloswap-horn', 'price_btc': '5.060202615733753', 'last_added': '17 horas'}
# {'symbol': 'metasfm', 'id': '21257', 'name': 'metasafemoon', 'price_btc': '0.000000002087373', 'last_added': '18 horas'}
# {'symbol': 'roar', 'id': '21256', 'name': 'roarts', 'price_btc': '0.002313848871225', 'last_added': '18 horas'}
# {'symbol': 'Passive', 'id': '21255', 'name': 'passive-token', 'price_btc': '1.148585792174994', 'last_added': '18 horas'}
# {'symbol': 'squid', 'id': '21254', 'name': 'squid-finance', 'price_btc': '0.000313175046003', 'last_added': '19 horas'}
# {'symbol': 'pine', 'id': '21253', 'name': 'atrollcity', 'price_btc': '0.000010633833683', 'last_added': '19 horas'}
# {'symbol': 'usdm', 'id': '21252', 'name': 'usd-mars', 'price_btc': '20.096692536646039', 'last_added': '19 horas'}
# {'symbol': 'kto', 'id': '21251', 'name': 'kounotori', 'price_btc': '0.000000008246156', 'last_added': '20 horas'}
# {'symbol': 'tpv', 'id': '21250', 'name': 'travgopv', 'price_btc': '0.000000023673359', 'last_added': '20 horas'}
# {'symbol': 'krx', 'id': '21249', 'name': 'kryza-exchange', 'price_btc': '0.014512572503695', 'last_added': '20 horas'}
# {'symbol': 'shibgx', 'id': '21248', 'name': 'shibagalaxy', 'price_btc': '0.000027350020868', 'last_added': '20 horas'}
# {'symbol': 'minecraft', 'id': '21247', 'name': 'synex-coin', 'price_btc': '0.029291160397930', 'last_added': '21 horas'}
# {'symbol': 'ksc', 'id': '21246', 'name': 'kingspeed', 'price_btc': '0.198505802940109', 'last_added': '21 horas'}
# {'symbol': 'vis', 'id': '21245', 'name': 'vigorus', 'price_btc': '0.089660970831477', 'last_added': '21 horas'}
# {'symbol': 'upt', 'id': '21243', 'name': 'upfund', 'price_btc': '0.000100903275165', 'last_added': '22 horas'}
# {'symbol': 'wamo', 'id': '21242', 'name': 'wamo', 'price_btc': '0.007301853465760', 'last_added': '23 horas'}
# {'symbol': 'rmtx', 'id': '21240', 'name': 'rematic-egc', 'price_btc': '0.000000008898948', 'last_added': '23 horas'}
# {'symbol': 'floshin', 'id': '21239', 'name': 'floshin', 'price_btc': '0.000000013390429', 'last_added': '23 horas'}
# {'symbol': 'ksamo', 'id': '21237', 'name': 'king-samo', 'price_btc': '0.000159055399025', 'last_added': '23 horas'}
# {'symbol': 'avamim', 'id': '21236', 'name': 'ava-mim', 'price_btc': '0.000000000089275', 'last_added': '23 horas'}
# {'symbol': 'val', 'id': '21235', 'name': 'vikings-finance', 'price_btc': '29.301957153716703', 'last_added': '24 horas'}
# {'symbol': 'bana', 'id': '21234', 'name': 'shibana', 'price_btc': '0.000000792133707', 'last_added': '24 horas'}
# {'symbol': 'fabric', 'id': '21233', 'name': 'metafabric', 'price_btc': '0.004748534261496', 'last_added': '24 horas'}
# {'symbol': 'metabc', 'id': '21232', 'name': 'meta-billionaires-club', 'price_btc': '0.003228349316683', 'last_added': '1 día'}
# {'symbol': 'zomfi', 'id': '21231', 'name': 'zomfi', 'price_btc': '0.087770802795034', 'last_added': '1 día'}
# {'symbol': 'crown', 'id': '21230', 'name': 'midasdao', 'price_btc': '180.021933367433263', 'last_added': '1 día'}
# {'symbol': 'vgb', 'id': '21229', 'name': 'vagabond', 'price_btc': '51.485786414240934', 'last_added': '1 día'}
# {'symbol': 'sod', 'id': '21228', 'name': 'son-of-doge', 'price_btc': '0.000000000000000', 'last_added': '1 día'}
# {'symbol': 'mat', 'id': '21227', 'name': 'monster-adventure-token', 'price_btc': '0.229258594734556', 'last_added': '1 día'}
# {'symbol': 'solar', 'id': '21226', 'name': 'solarmine', 'price_btc': '0.009502265719345', 'last_added': '1 día'}
# {'symbol': 'kxa', 'id': '21225', 'name': 'kryxivia-game', 'price_btc': '0.138759359476152', 'last_added': '1 día'}
# {'symbol': '$sbc', 'id': '21224', 'name': 'superbrain-capital-dao', 'price_btc': '0.000200031901006', 'last_added': '1 día'}
# {'symbol': 'wnt', 'id': '21223', 'name': 'wicrypt', 'price_btc': '0.199286997216020', 'last_added': '1 día'}
# {'symbol': 'fint', 'id': '21222', 'name': 'fintropy', 'price_btc': '0.245028485935001', 'last_added': '1 día'}
# {'symbol': 'ecc', 'id': '21221', 'name': 'empire-capital-token', 'price_btc': '0.017482273798206', 'last_added': '2 días'}
# {'symbol': 'bpkr', 'id': '21220', 'name': 'blackpoker', 'price_btc': '0.053208624639239', 'last_added': '2 días'}
# {'symbol': 'mbnb', 'id': '21219', 'name': 'magic-bnb', 'price_btc': '0.000006890268907', 'last_added': '2 días'}
# {'symbol': 'tgb', 'id': '21218', 'name': 'traders-global-business', 'price_btc': '0.004951859251739', 'last_added': '2 días'}
# {'symbol': 'smhdoge', 'id': '21217', 'name': 'supermegahyperdoge', 'price_btc': '0.000210898897003', 'last_added': '2 días'}
# {'symbol': 'zns', 'id': '21216', 'name': 'zeronauts', 'price_btc': '0.025819733429830', 'last_added': '2 días'}
# {'symbol': 'drug', 'id': '21215', 'name': 'dopewarz', 'price_btc': '0.084888137960129', 'last_added': '2 días'}
# {'symbol': 'yon', 'id': '21214', 'name': 'yesorno', 'price_btc': '0.005806131323210', 'last_added': '3 días'}
# {'symbol': 'dw', 'id': '21213', 'name': 'dawn-wars', 'price_btc': '3.294287105728629', 'last_added': '3 días'}
# {'symbol': 'plastik', 'id': '21212', 'name': 'plastiks', 'price_btc': '0.070136283795660', 'last_added': '3 días'}
# {'symbol': 'umy', 'id': '21211', 'name': 'karastar-umy', 'price_btc': '0.606590695591014', 'last_added': '3 días'}
# {'symbol': 'orne', 'id': '21210', 'name': 'orne', 'price_btc': '0.040836405374763', 'last_added': '3 días'}
# {'symbol': 'spin', 'id': '21209', 'name': 'spintop', 'price_btc': '0.296451324706845', 'last_added': '3 días'}
# {'symbol': 'charm', 'id': '21208', 'name': 'charm', 'price_btc': '0.000230124809389', 'last_added': '3 días'}
# {'symbol': 'crt', 'id': '21207', 'name': 'crystal-wallet', 'price_btc': '0.032263102016607', 'last_added': '3 días'}
# {'symbol': 'BTCBR', 'id': '21205', 'name': 'bitcoin-br', 'price_btc': '7.797725885299618', 'last_added': '3 días'}
# {'symbol': 'SFC', 'id': '21204', 'name': 'solar-full-cycle', 'price_btc': '0.002924181790390', 'last_added': '3 días'}
# {'symbol': 'shin', 'id': '21203', 'name': 'shinomics', 'price_btc': '0.000000818096180', 'last_added': '3 días'}
# {'symbol': 'dod', 'id': '21202', 'name': 'defender-of-doge', 'price_btc': '0.000000090203514', 'last_added': '4 días'}
# {'symbol': 'DOGERISEUP', 'id': '21201', 'name': 'doge-rise-up', 'price_btc': '0.000000002477796', 'last_added': '4 días'}
# {'symbol': '$PLKG', 'id': '21199', 'name': 'polkago', 'price_btc': '0.000636037610083', 'last_added': '4 días'}
# {'symbol': 'Aurora', 'id': '21198', 'name': 'aurora-token', 'price_btc': '0.000000000166949', 'last_added': '4 días'}
# {'symbol': 'trick', 'id': '21197', 'name': 'trick', 'price_btc': '46.864097210413838', 'last_added': '4 días'}
# {'symbol': 'avapay', 'id': '21196', 'name': 'avapay', 'price_btc': '0.000000000967414', 'last_added': '4 días'}
# {'symbol': 'm31', 'id': '21194', 'name': 'andromeda', 'price_btc': '0.142607232729936', 'last_added': '4 días'}
# {'symbol': 'YSHIBAINU', 'id': '21193', 'name': 'yooshiba-inu', 'price_btc': '0.000000003222119', 'last_added': '4 días'}
# {'symbol': 'xsuter', 'id': '15683', 'name': 'xsuter', 'price_btc': '241.354820729225054', 'last_added': '4 días'}
# {'symbol': 'cox', 'id': '21191', 'name': 'coxswap', 'price_btc': '0.000000033445312', 'last_added': '4 días'}
# {'symbol': 'sfc', 'id': '21190', 'name': 'small-fish-cookie', 'price_btc': '2.068629457832938', 'last_added': '4 días'}
# {'symbol': 'buffs', 'id': '21189', 'name': 'buffswap', 'price_btc': '0.218239473806703', 'last_added': '4 días'}
# {'symbol': 'kng', 'id': '21188', 'name': 'kanga-exchange', 'price_btc': '8.074096581362264', 'last_added': '4 días'}
# {'symbol': 'mtgm', 'id': '21187', 'name': 'metagaming', 'price_btc': '0.000017071187900', 'last_added': '4 días'}
# {'symbol': 'nftndr', 'id': '21186', 'name': 'nftinder', 'price_btc': '0.000026271288037', 'last_added': '4 días'}
# {'symbol': 'lez', 'id': '21185', 'name': 'peoplez', 'price_btc': '0.523426007134675', 'last_added': '4 días'}
# {'symbol': 'mono', 'id': '21184', 'name': 'the-monopolist', 'price_btc': '0.042544157858808', 'last_added': '4 días'}
# {'symbol': 'eth2x-fli-p', 'id': '21183', 'name': 'index-coop-eth-2x-flexible-leverage-index-polygon', 'price_btc': '73.247494502805395', 'last_added': '4 días'}
# {'symbol': 'crown', 'id': '21182', 'name': 'kingpad', 'price_btc': '5.239172461625851', 'last_added': '4 días'}
# {'symbol': 'zodi', 'id': '21181', 'name': 'zodium', 'price_btc': '0.339020807869010', 'last_added': '4 días'}
# {'symbol': 'fam', 'id': '21180', 'name': 'family', 'price_btc': '1.019753577928347', 'last_added': '4 días'}
# {'symbol': 'metacex', 'id': '21179', 'name': 'metaverse-exchange', 'price_btc': '0.006184367360504', 'last_added': '4 días'}
# {'symbol': 'vr', 'id': '21178', 'name': 'victoria-vr', 'price_btc': '0.338008760379591', 'last_added': '4 días'}
# {'symbol': 'moo', 'id': '21177', 'name': 'moomonster', 'price_btc': '0.569405557512839', 'last_added': '4 días'}
# {'symbol': 'xdg', 'id': '21176', 'name': 'decentral-games-governance', 'price_btc': '0.479023331781280', 'last_added': '4 días'}
# {'symbol': 'INF', 'id': '21175', 'name': 'infam', 'price_btc': '2.556427877844144', 'last_added': '5 días'}
# {'symbol': 'XL', 'id': '21174', 'name': 'xolo-inu', 'price_btc': '0.001002175757220', 'last_added': '5 días'}
# {'symbol': 'dg', 'id': '21173', 'name': 'decentral-games', 'price_btc': '0.460115548571198', 'last_added': '5 días'}
# {'symbol': 'mvc', 'id': '21172', 'name': 'multiverse-capital', 'price_btc': '0.000024598187397', 'last_added': '5 días'}
# {'symbol': 'drag', 'id': '21171', 'name': 'drachen-lord', 'price_btc': '0.017396840566910', 'last_added': '5 días'}
# {'symbol': 'shibli', 'id': '21170', 'name': 'studio-shibli', 'price_btc': '0.000000000794763', 'last_added': '5 días'}
# {'symbol': 'cheez', 'id': '21169', 'name': 'cheesedao', 'price_btc': '46.307821911942405', 'last_added': '5 días'}
# {'symbol': 'xeeb', 'id': '21168', 'name': 'xeebster', 'price_btc': '0.000000002737376', 'last_added': '5 días'}
# {'symbol': 'ds$', 'id': '21167', 'name': 'diamondshiba', 'price_btc': '0.000000855070399', 'last_added': '5 días'}
# {'symbol': 'AVohminu', 'id': '21166', 'name': 'ohm-inu-dao', 'price_btc': '0.000001667558854', 'last_added': '5 días'}
# {'symbol': 'gamingshiba', 'id': '21165', 'name': 'gamingshiba', 'price_btc': '0.000000000020240', 'last_added': '5 días'}
# {'symbol': 'honeyd', 'id': '21164', 'name': 'honey-deluxe', 'price_btc': '25.922683039966557', 'last_added': '5 días'}
# {'symbol': 'oooor', 'id': '21163', 'name': 'oooor-finance', 'price_btc': '0.000165097956361', 'last_added': '5 días'}
